# %%
# Primeira parte
import pandas as pd
import pymongo
import urllib.parse

# Definir o caminho do arquivo CSV
csv_path = r"C:\Users\Aluno\Documents\Santt\Banco-NoSQL\MongoDB\Mongo-API(parte3)\IMDB top 1000.csv"

# Ler o CSV usando Pandas
df = pd.read_csv(csv_path)

# %%
print(df.head(6))
# Out:
#    Unnamed: 0                                              Title Certificate  \
# 0           0                 1. The Shawshank Redemption (1994)           R
# 1           1                            2. The Godfather (1972)           R
# 2           2                          3. The Dark Knight (2008)       PG-13
# 3           3                   4. The Godfather: Part II (1974)           R
# 4           4  5. The Lord of the Rings: The Return of the Ki...       PG-13
# 5           5                             6. Pulp Fiction (1994)           R
#
#   Duration                     Genre  Rate  Metascore  \
# 0  142 min                     Drama   9.3       80.0
# 1  175 min              Crime, Drama   9.2      100.0
# 2  152 min      Action, Crime, Drama   9.0       84.0
# 3  202 min              Crime, Drama   9.0       90.0
# 4  201 min  Action, Adventure, Drama   8.9       94.0
# 5  154 min              Crime, Drama   8.9       94.0
#
#                                          Description  \
# 0  Two imprisoned men bond over a number of years...
# 1  The aging patriarch of an organized crime dyna...
# 2  When the menace known as the Joker wreaks havo...
# 3  The early life and career of Vito Corleone in ...
# 4  Gandalf and Aragorn lead the World of Men agai...
# 5  The lives of two mob hitmen, a boxer, a gangst...
#
#                                                 Cast  \
# 0  Director: Frank Darabont | Stars: Tim Robbins,...
# 1  Director: Francis Ford Coppola | Stars: Marlon...
# 2  Director: Christopher Nolan | Stars: Christian...
# 3  Director: Francis Ford Coppola | Stars: Al Pac...
# 4  Director: Peter Jackson | Stars: Elijah Wood, ...
# 5  Director: Quentin Tarantino | Stars: John Trav...
#
#                                  Info
# 0   Votes: 2,295,987 | Gross: $28.34M
# 1  Votes: 1,584,782 | Gross: $134.97M
# 2  Votes: 2,260,649 | Gross: $534.86M
# 3   Votes: 1,107,253 | Gross: $57.30M
# 4  Votes: 1,614,369 | Gross: $377.85M
# 5  Votes: 1,792,919 | Gross: $107.93M

# %%
# Segunda parte
import pymongo
import urllib.parse

# Definir usuário e senha
username = "4rthurmsantos00_db_user"
password = "oADfBSFNh7blVxsW"

# Codificar a senha (caso tenha caracteres especiais)
password_encoded = urllib.parse.quote_plus(password)

# Criar a URI corretamente formatada
MONGO_URI = f"mongodb+srv://{username}:{password_encoded}@cluster0.eowrtnl.mongodb.net/?appName=Cluster0"

# Conectar ao MongoDB Atlas
client = pymongo.MongoClient(MONGO_URI)

# Acessar o banco e a coleção
db = client["filmes"]
collection = db["filmes-series"]

print("Conexão com MongoDB Atlas estabelecida!")
# Out:
# Conexão com MongoDB Atlas estabelecida!

# %%
# Terceira parte

# Converte o DataFrame (df) em uma lista de dicionários, onde cada linha vira um "registro" (record) separado.
# df.to_dict() → transforma o DataFrame em um dicionário.
# orient="records" → define o formato da conversão: cada linha = 1 dicionário (ideal para inserir no MongoDB).
dados_json = df.to_dict(orient="records")

# Ou seja: orient="records" instrui o pandas a gerar uma lista de documentos JSON, 
# cada um representando uma linha da tabela, que o MongoDB entende perfeitamente.

# Insere todos os documentos (dicionários) da lista 'dados_json' dentro da coleção MongoDB de uma só vez.
# 'collection' → é o objeto que representa a coleção (tabela) no banco MongoDB.
# 'insert_many()' → comando do PyMongo que insere múltiplos documentos de uma vez (em lote).
# 'dados_json' → é a lista de dicionários criada antes (cada item = um documento/linha).
collection.insert_many(dados_json)

print(" Dados enviados para o MongoDB Atlas com sucesso!")
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[5], line 15
#      11 # Insere todos os documentos (dicionários) da lista 'dados_json' dentro da coleção MongoDB de uma só vez.
#      12 # 'collection' → é o objeto que representa a coleção (tabela) no banco MongoDB.
#      13 # 'insert_many()' → comando do PyMongo que insere múltiplos documentos de uma vez (em lote).
#      14 # 'dados_json' → é a lista de dicionários criada antes (cada item = um documento/linha).
# ---> 15 collection.insert_many(dados_json)
#      16
#      17 print(" Dados enviados para o MongoDB Atlas com sucesso!")
#
# File c:\Users\Aluno\Documents\Santt\Banco-NoSQL\MongoDB\Mongo-API(parte3)\venv\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\Aluno\Documents\Santt\Banco-NoSQL\MongoDB\Mongo-API(parte3)\venv\Lib\site-packages\pymongo\synchronous\collection.py:975, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     973 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     974 blk.ops = list(gen())
# --> 975 blk.execute(write_concern, session, _Op.INSERT)
#     976 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File c:\Users\Aluno\Documents\Santt\Banco-NoSQL\MongoDB\Mongo-API(parte3)\venv\Lib\site-packages\pymongo\synchronous\bulk.py:751, in _Bulk.execute(self, write_concern, session, operation)
#     749         return None
#     750 else:
# --> 751     return self.execute_command(generator, write_concern, session, operation)
#
# File c:\Users\Aluno\Documents\Santt\Banco-NoSQL\MongoDB\Mongo-API(parte3)\venv\Lib\site-packages\pymongo\synchronous\bulk.py:604, in _Bulk.execute_command(self, generator, write_concern, session, operation)
#     593     self._execute_command(
#     594         generator,
#     595         write_concern,
#    (...)    600         full_result,
#     601     )
#     603 client = self.collection.database.client
# --> 604 _ = client._retryable_write(
#     605     self.is_retryable,
#     606     retryable_bulk,
#     607     session,
#     608     operation,
#     609     bulk=self,  # type: ignore[arg-type]
#     610     operation_id=op_id,
#     611 )
#     613 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#     614     _raise_bulk_write_error(full_result)
#
# File c:\Users\Aluno\Documents\Santt\Banco-NoSQL\MongoDB\Mongo-API(parte3)\venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:2083, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    2069 """Execute an operation with consecutive retries if possible
#    2070
#    2071 Returns func()'s return value on success. On error retries the same
#    (...)   2080 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    2081 """
#    2082 with self._tmp_session(session) as s:
# -> 2083     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File c:\Users\Aluno\Documents\Santt\Banco-NoSQL\MongoDB\Mongo-API(parte3)\venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:1968, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1963 # Ensure that the options supports retry_writes and there is a valid session not in
#    1964 # transaction, otherwise, we will not support retry behavior for this txn.
#    1965 retryable = bool(
#    1966     retryable and self.options.retry_writes and session and not session.in_transaction
#    1967 )
# -> 1968 return self._retry_internal(
#    1969     func=func,
#    1970     session=session,
#    1971     bulk=bulk,
#    1972     operation=operation,
#    1973     retryable=retryable,
#    1974     operation_id=operation_id,
#    1975 )
#
# File c:\Users\Aluno\Documents\Santt\Banco-NoSQL\MongoDB\Mongo-API(parte3)\venv\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\Aluno\Documents\Santt\Banco-NoSQL\MongoDB\Mongo-API(parte3)\venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:2014, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)   1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)   2001     :return: Output of the calling func()
#    2002     """
#    2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
# -> 2014     ).run()
#
# File c:\Users\Aluno\Documents\Santt\Banco-NoSQL\MongoDB\Mongo-API(parte3)\venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:2763, in _ClientConnectionRetryable.run(self)
#    2761 self._check_last_error(check_csot=True)
#    2762 try:
# -> 2763     return self._read() if self._is_read else self._write()
#    2764 except ServerSelectionTimeoutError:
#    2765     # The application may think the write was never attempted
#    2766     # if we raise ServerSelectionTimeoutError on the retry
#    2767     # attempt. Raise the original exception instead.
#    2768     self._check_last_error()
#
# File c:\Users\Aluno\Documents\Santt\Banco-NoSQL\MongoDB\Mongo-API(parte3)\venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:2873, in _ClientConnectionRetryable._write(self)
#    2871 max_wire_version = 0
#    2872 is_mongos = False
# -> 2873 self._server = self._get_server()
#    2874 with self._client._checkout(self._server, self._session) as conn:
#    2875     max_wire_version = conn.max_wire_version
#
# File c:\Users\Aluno\Documents\Santt\Banco-NoSQL\MongoDB\Mongo-API(parte3)\venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:2856, in _ClientConnectionRetryable._get_server(self)
#    2851 def _get_server(self) -> Server:
#    2852     """Retrieves a server object based on provided object context
#    2853
#    2854     :return: Abstraction to connect to server
#    2855     """
# -> 2856     return self._client._select_server(
#    2857         self._server_selector,
#    2858         self._session,
#    2859         self._operation,
#    2860         address=self._address,
#    2861         deprioritized_servers=self._deprioritized_servers,
#    2862         operation_id=self._operation_id,
#    2863     )
#
# File c:\Users\Aluno\Documents\Santt\Banco-NoSQL\MongoDB\Mongo-API(parte3)\venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:1833, in MongoClient._select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1831             raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1832     else:
# -> 1833         server = topology.select_server(
#    1834             server_selector,
#    1835             operation,
#    1836             deprioritized_servers=deprioritized_servers,
#    1837             operation_id=operation_id,
#    1838         )
#    1839     return server
#    1840 except PyMongoError as exc:
#    1841     # Server selection errors in a transaction are transient.
#
# File c:\Users\Aluno\Documents\Santt\Banco-NoSQL\MongoDB\Mongo-API(parte3)\venv\Lib\site-packages\pymongo\synchronous\topology.py:428, in Topology.select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     418 def select_server(
#     419     self,
#     420     selector: Callable[[Selection], Selection],
#    (...)    425     operation_id: Optional[int] = None,
#     426 ) -> Server:
#     427     """Like select_servers, but choose a random server if several match."""
# --> 428     server = self._select_server(
#     429         selector,
#     430         operation,
#     431         server_selection_timeout,
#     432         address,
#     433         deprioritized_servers,
#     434         operation_id=operation_id,
#     435     )
#     436     if _csot.get_timeout():
#     437         _csot.set_rtt(server.description.min_round_trip_time)
#
# File c:\Users\Aluno\Documents\Santt\Banco-NoSQL\MongoDB\Mongo-API(parte3)\venv\Lib\site-packages\pymongo\synchronous\topology.py:402, in Topology._select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     393 def _select_server(
#     394     self,
#     395     selector: Callable[[Selection], Selection],
#    (...)    400     operation_id: Optional[int] = None,
#     401 ) -> Server:
# --> 402     servers = self.select_servers(
#     403         selector,
#     404         operation,
#     405         server_selection_timeout,
#     406         address,
#     407         operation_id,
#     408         deprioritized_servers,
#     409     )
#     410     if len(servers) == 1:
#     411         return servers[0]
#
# File c:\Users\Aluno\Documents\Santt\Banco-NoSQL\MongoDB\Mongo-API(parte3)\venv\Lib\site-packages\pymongo\synchronous\topology.py:298, in Topology.select_servers(self, selector, operation, server_selection_timeout, address, operation_id, deprioritized_servers)
#     295     self.cleanup_monitors()
#     297 with self._lock:
# --> 298     server_descriptions = self._select_servers_loop(
#     299         selector,
#     300         server_timeout,
#     301         operation,
#     302         operation_id,
#     303         address,
#     304         deprioritized_servers=deprioritized_servers,
#     305     )
#     307     return [
#     308         cast(Server, self.get_server_by_address(sd.address)) for sd in server_descriptions
#     309     ]
#
# File c:\Users\Aluno\Documents\Santt\Banco-NoSQL\MongoDB\Mongo-API(parte3)\venv\Lib\site-packages\pymongo\synchronous\topology.py:359, in Topology._select_servers_loop(self, selector, timeout, operation, operation_id, address, deprioritized_servers)
#     348     if _SERVER_SELECTION_LOGGER.isEnabledFor(logging.DEBUG):
#     349         _debug_log(
#     350             _SERVER_SELECTION_LOGGER,
#     351             message=_ServerSelectionStatusMessage.FAILED,
#    (...)    357             failure=self._error_message(selector),
#     358         )
# --> 359     raise ServerSelectionTimeoutError(
#     360         f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     361     )
#     363 if not logged_waiting:
#     364     _debug_log(
#     365         _SERVER_SELECTION_LOGGER,
#     366         message=_ServerSelectionStatusMessage.WAITING,
#    (...)    372         remainingTimeMS=int(1000 * (end_time - time.monotonic())),
#     373     )
#
# ServerSelectionTimeoutError: ac-cnk9lrx-shard-00-00.eowrtnl.mongodb.net:27017: timed out (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),ac-cnk9lrx-shard-00-02.eowrtnl.mongodb.net:27017: timed out (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),ac-cnk9lrx-shard-00-01.eowrtnl.mongodb.net:27017: timed out (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 69d5967ff4e1d3ae7c15c9b6, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-cnk9lrx-shard-00-00.eowrtnl.mongodb.net', 27017) server_type: Unknown, rtt: None, error=NetworkTimeout('ac-cnk9lrx-shard-00-00.eowrtnl.mongodb.net:27017: timed out (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>, <ServerDescription ('ac-cnk9lrx-shard-00-01.eowrtnl.mongodb.net', 27017) server_type: Unknown, rtt: None, error=NetworkTimeout('ac-cnk9lrx-shard-00-01.eowrtnl.mongodb.net:27017: timed out (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>, <ServerDescription ('ac-cnk9lrx-shard-00-02.eowrtnl.mongodb.net', 27017) server_type: Unknown, rtt: None, error=NetworkTimeout('ac-cnk9lrx-shard-00-02.eowrtnl.mongodb.net:27017: timed out (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>

# %% [markdown]
# Consultas no Banco

# %%
for doc in collection.find({"Genre": "Drama"}):
    print(doc["Title"], "-", doc["Rate"])

# Retorna todos os filmes onde o campo "Genre" é "Drama".
# Você pode alterar para "Action", "Comedy", etc.
# Out:
# 1. The Shawshank Redemption (1994) - 9.3
# 10. Fight Club (1999) - 8.8
# 19. One Flew Over the Cuckoo's Nest (1975) - 8.7
# 40. American History X (1998) - 8.5
# 45. Cinema Paradiso (1988) - 8.5
# 54. Capernaum (2018) - 8.4
# 88. The Hunt (2012) - 8.3
# 91. 7 Kogustaki Mucize (2019) - 8.3
# 98. Requiem for a Dream (2000) - 8.3
# 99. American Beauty (1999) - 8.3
# 122. Ikiru (1952) - 8.3
# 123. Bicycle Thieves (1948) - 8.3
# 141. Udaan (2010) - 8.2
# 149. There Will Be Blood (2007) - 8.2
# 153. Black (2005) - 8.2
# 155. Swades (2004) - 8.2
# 185. Tokyo Story (1953) - 8.2
# 187. All About Eve (1950) - 8.2
# 197. Mommy (I) (2014) - 8.1
# 202. Winter Sleep (2014) - 8.1
# 223. Gran Torino (2008) - 8.1
# 252. Trainspotting (1996) - 8.1
# 267. Paris, Texas (1984) - 8.1
# 272. Fanny and Alexander (1982) - 8.1
# 278. Network (1976) - 8.1
# 283. Cries & Whispers (1972) - 8.1
# 295. The Virgin Spring (1960) - 8.1
# 301. Nights of Cabiria (1957) - 8.1
# 335. Short Term 12 (2013) - 8.0
# 346. The Help (2011) - 8.0
# 351. My Name Is Khan (2010) - 8.0
# 368. The Return (2003) - 8.0
# 382. Magnolia (1999) - 8.0
# 387. The Celebration (1998) - 8.0
# 388. Central Station (1998) - 8.0
# 391. Sling Blade (1996) - 8.0
# 398. Scent of a Woman (1992) - 8.0
# 301. Nights of Cabiria (1957) - 8.1
# 335. Short Term 12 (2013) - 8.0
# 346. The Help (2011) - 8.0
# 351. My Name Is Khan (2010) - 8.0
# 368. The Return (2003) - 8.0
# 382. Magnolia (1999) - 8.0
# 387. The Celebration (1998) - 8.0
# 388. Central Station (1998) - 8.0
# 391. Sling Blade (1996) - 8.0
# 398. Scent of a Woman (1992) - 8.0
# 301. Nights of Cabiria (1957) - 8.1
# 335. Short Term 12 (2013) - 8.0
# 346. The Help (2011) - 8.0
# 351. My Name Is Khan (2010) - 8.0
# 368. The Return (2003) - 8.0
# 382. Magnolia (1999) - 8.0
# 387. The Celebration (1998) - 8.0
# 388. Central Station (1998) - 8.0
# 391. Sling Blade (1996) - 8.0
# 398. Scent of a Woman (1992) - 8.0
# 301. Nights of Cabiria (1957) - 8.1
# 335. Short Term 12 (2013) - 8.0
# 346. The Help (2011) - 8.0
# 351. My Name Is Khan (2010) - 8.0
# 368. The Return (2003) - 8.0
# 382. Magnolia (1999) - 8.0
# 387. The Celebration (1998) - 8.0
# 388. Central Station (1998) - 8.0
# 391. Sling Blade (1996) - 8.0
# 398. Scent of a Woman (1992) - 8.0
# 301. Nights of Cabiria (1957) - 8.1
# 335. Short Term 12 (2013) - 8.0
# 346. The Help (2011) - 8.0
# 351. My Name Is Khan (2010) - 8.0
# 368. The Return (2003) - 8.0
# 382. Magnolia (1999) - 8.0
# 387. The Celebration (1998) - 8.0
# 388. Central Station (1998) - 8.0
# 391. Sling Blade (1996) - 8.0
# 398. Scent of a Woman (1992) - 8.0
# 301. Nights of Cabiria (1957) - 8.1
# 335. Short Term 12 (2013) - 8.0
# 346. The Help (2011) - 8.0
# 351. My Name Is Khan (2010) - 8.0
# 368. The Return (2003) - 8.0
# 382. Magnolia (1999) - 8.0
# 387. The Celebration (1998) - 8.0
# 388. Central Station (1998) - 8.0
# 391. Sling Blade (1996) - 8.0
# 398. Scent of a Woman (1992) - 8.0
# 301. Nights of Cabiria (1957) - 8.1
# 335. Short Term 12 (2013) - 8.0
# 346. The Help (2011) - 8.0
# 351. My Name Is Khan (2010) - 8.0
# 368. The Return (2003) - 8.0
# 382. Magnolia (1999) - 8.0
# 387. The Celebration (1998) - 8.0
# 388. Central Station (1998) - 8.0
# 391. Sling Blade (1996) - 8.0
# 398. Scent of a Woman (1992) - 8.0
# 301. Nights of Cabiria (1957) - 8.1

# %%
for doc in collection.find({"Rate": {"$gt": 8.5}}):
    print(doc["Title"], "-", doc["Rate"])

# O operador $gt significa greater than (maior que).
# Mostra filmes com nota superior a 8.5 no IMDB.
# Out:
# 1. The Shawshank Redemption (1994) - 9.3
# 2. The Godfather (1972) - 9.2
# 3. The Dark Knight (2008) - 9.0
# 4. The Godfather: Part II (1974) - 9.0
# 5. The Lord of the Rings: The Return of the King (2003) - 8.9
# 6. Pulp Fiction (1994) - 8.9
# 7. Schindler's List (1993) - 8.9
# 8. 12 Angry Men (1957) - 8.9
# 9. Inception (2010) - 8.8
# 10. Fight Club (1999) - 8.8
# 11. The Lord of the Rings: The Fellowship of the Ring (2001) - 8.8
# 12. Forrest Gump (1994) - 8.8
# 13. The Good, the Bad and the Ugly (1966) - 8.8
# 14. Hamilton (2020) - 8.7
# 15. The Lord of the Rings: The Two Towers (2002) - 8.7
# 16. The Matrix (1999) - 8.7
# 17. Goodfellas (1990) - 8.7
# 18. Star Wars: Episode V - The Empire Strikes Back (1980) - 8.7
# 19. One Flew Over the Cuckoo's Nest (1975) - 8.7
# 20. Parasite (2019) - 8.6
# 21. Interstellar (2014) - 8.6
# 22. City of God (2002) - 8.6
# 23. Spirited Away (2001) - 8.6
# 24. Saving Private Ryan (1998) - 8.6
# 25. The Green Mile (1999) - 8.6
# 26. Life Is Beautiful (1997) - 8.6
# 27. Se7en (1995) - 8.6
# 28. The Silence of the Lambs (1991) - 8.6
# 29. Star Wars: Episode IV - A New Hope (1977) - 8.6
# 30. Harakiri (1962) - 8.6
# 31. Seven Samurai (1954) - 8.6
# 32. It's a Wonderful Life (1946) - 8.6

# %%
top5 = collection.find().sort("Rate", -1).limit(5)
for doc in top5:
    print(doc["Title"], "-", doc["Rate"])

# Ordena do maior para o menor (-1) e mostra apenas 5 resultados.
# Out:
# 1. The Shawshank Redemption (1994) - 9.3
# 2. The Godfather (1972) - 9.2
# 4. The Godfather: Part II (1974) - 9.0
# 3. The Dark Knight (2008) - 9.0
# 5. The Lord of the Rings: The Return of the King (2003) - 8.9

# %%
query = {"Genre": "Drama", "Metascore": {"$gt": 90}}
for doc in collection.find(query, {"Title": 1, "Metascore": 1, "_id": 0}):
    print(doc)

# Filtra por dois critérios: gênero e metascore alto.
# O segundo parâmetro {} define quais campos mostrar (1 = incluir, 0 = excluir).
# Out:
# {'Title': '149. There Will Be Blood (2007)', 'Metascore': 93.0}
# {'Title': '187. All About Eve (1950)', 'Metascore': 98.0}
# {'Title': '272. Fanny and Alexander (1982)', 'Metascore': 100.0}

# %%
count = collection.count_documents({"Certificate": "R"})
print("Total de filmes com classificação R:", count)

## Conta quantos documentos possuem o valor "R" no campo "Certificate".
# Out:
# Total de filmes com classificação R: 345

# %%
# No caso funciona rodando no próprio Banco na Nuvem

# Mostra todos os documentos onde o campo Genre é exatamente "Drama".
{ "Genre": "Drama" }

# Filmes com nota (Rate) maior que 9
{ "Rate": { "$gt": 9 } }

# Você também pode combinar com expressões regulares para buscas por texto:
{ "Description": { "$regex": "prison", "$options": "i" } }
