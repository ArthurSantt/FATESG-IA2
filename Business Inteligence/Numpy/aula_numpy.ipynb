# %%
import numpy as np

# %%
vet = np.array([1,2,3,6,8,9,10,11,13,15,101,15,13,12,3,1])
vet
# Out:
# array([  1,   2,   3,   6,   8,   9,  10,  11,  13,  15, 101,  15,  13,
#         12,   3,   1])

# %%
type(vet)
# Out:
# numpy.ndarray

# %%
vet2 = np.array([1,2,3,4,5,])
vet2.cumsum()
# Out:
# array([ 1,  3,  6, 10, 15])

# %%
print(vet[4])
# Out:
# 8

# %%
vet[8]=-1
vet
# Out:
# array([  1,   2,   3,   6,   8,   9,  10,  11,  -1,  15, 101,  15,  13,
#         12,   3,   1])

# %%
vet=np.append(vet,202)
vet
# Out:
# array([  1,   2,   3,   6,   8,   9,  10,  11,  -1,  15, 101,  15,  13,
#         12,   3,   1, 202, 202])

# %%
vet=vet[:-1]
vet
# Out:
# array([  1,   2,   3,   6,   8,   9,  10,  11,  -1,  15, 101,  15,  13,
#         12,   3])

# %%
vetor2x3=np.array([[1,2,3],[4,5,6]])
vetor2x3
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
vetor2x3.shape
# Out:
# (2, 3)

# %%
vetor3x2=np.array([[1,2],[3,4],[5,6]])
vetor3x2
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
vetor3x2.shape
# Out:
# (3, 2)

# %%
unicos_vet=np.unique(vet)
unicos_vet
# Out:
# array([ -1,   1,   2,   3,   6,   8,   9,  10,  11,  12,  13,  15, 101])

# %%
idades = np.array([44,45,23,23,28,19,20,19,17,51,29,28,31,32])
mediaIA2 = round(idades.mean(),3)
mediaIA2
# Out:
# np.float64(29.214)

# %%
j = np.unique(idades)
j
# Out:
# array([17, 19, 20, 23, 28, 29, 31, 32, 44, 45, 51])
